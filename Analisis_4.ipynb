# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Entrenamiento_1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     ID    Region   Territory  \
# 0           0  27761      EMEA        None
# 1           1  27760      EMEA        None
# 2           2  27446  Americas  NW America
# 3           3  16808  Americas  NW America
# 4           4  16805  Americas  NW America
#
#    Pricing, Delivery_Terms_Quote_Approval  Pricing, Delivery_Terms_Approved  \
# 0                                    True                              True
# 1                                   False                             False
# 2                                   False                             False
# 3                                    True                             False
# 4                                    True                             False
#
#    Bureaucratic_Code_0_Approval  Bureaucratic_Code_0_Approved  \
# 0                          True                          True
# 1                         False                         False
# 2                         False                         False
# 3                          True                         False
# 4                          True                         False
#
#      Bureaucratic_Code Account_Created_Date  ... Planned_Delivery_End_Date  \
# 0  Bureaucratic_Code_4           2015-06-16  ...                2016-06-30
# 1  Bureaucratic_Code_4           2015-06-16  ...                2016-01-20
# 2  Bureaucratic_Code_4           2015-04-21  ...                2016-01-25
# 3  Bureaucratic_Code_5           2013-07-27  ...                2018-03-31
# 4  Bureaucratic_Code_5           2013-07-27  ...                2018-02-28
#
#         Month Delivery_Quarter Delivery_Year  TRF Total_Amount_Currency  \
# 0  2016-05-01               Q2          2016   10                   EUR
# 1  2016-01-01               Q1          2016    0                   EUR
# 2  2016-01-01               Q1          2016    0                   USD
# 3  2018-02-01               Q1          2018   14                   USD
# 4  2018-02-01               Q1          2018   25                   USD
#
#   Total_Amount Total_Taxable_Amount_Currency Total_Taxable_Amount        Stage
# 0    5272800.0                           EUR            5272800.0  Closed Lost
# 1      48230.0                           EUR              48230.0   Closed Won
# 2      83865.6                           USD              83865.6   Closed Won
# 3    7421881.5                           USD            7421881.5  Closed Lost
# 4   13357192.5                           USD           13357192.5  Closed Lost
#
# [5 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 49 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              16947 non-null  int64
#  1   ID                                      16947 non-null  int64
#  2   Region                                  16947 non-null  object
#  3   Territory                               16947 non-null  object
#  4   Pricing, Delivery_Terms_Quote_Approval  16947 non-null  bool
#  5   Pricing, Delivery_Terms_Approved        16947 non-null  bool
#  6   Bureaucratic_Code_0_Approval            16947 non-null  bool
#  7   Bureaucratic_Code_0_Approved            16947 non-null  bool
#  8   Bureaucratic_Code                       16947 non-null  object
#  9   Account_Created_Date                    16947 non-null  object
#  10  Source                                  16947 non-null  object
#  11  Billing_Country                         16947 non-null  object
#  12  Account_Name                            16947 non-null  object
#  13  Opportunity_Name                        16947 non-null  object
#  14  Opportunity_ID                          16947 non-null  int64
#  15  Sales_Contract_No                       16947 non-null  object
#  16  Account_Owner                           16947 non-null  object
#  17  Opportunity_Owner                       16947 non-null  object
#  18  Account_Type                            16947 non-null  object
#  19  Opportunity_Type                        16947 non-null  object
#  20  Quote_Type                              16947 non-null  object
#  21  Delivery_Terms                          16947 non-null  object
#  22  Opportunity_Created_Date                16947 non-null  object
#  23  Brand                                   16947 non-null  object
#  24  Product_Type                            16947 non-null  object
#  25  Size                                    16947 non-null  object
#  26  Product_Category_B                      16947 non-null  object
#  27  Price                                   16947 non-null  object
#  28  Currency                                16947 non-null  object
#  29  Quote_Expiry_Date                       12322 non-null  object
#  30  Last_Modified_Date                      16947 non-null  object
#  31  Last_Modified_By                        16947 non-null  object
#  32  Product_Family                          16947 non-null  object
#  33  Product_Name                            16947 non-null  object
#  34  ASP_Currency                            16947 non-null  object
#  35  ASP                                     13738 non-null  float64
#  36  ASP_(converted)_Currency                16947 non-null  object
#  37  ASP_(converted)                         13738 non-null  float64
#  38  Planned_Delivery_Start_Date             16947 non-null  object
#  39  Planned_Delivery_End_Date               16872 non-null  object
#  40  Month                                   16947 non-null  object
#  41  Delivery_Quarter                        16947 non-null  object
#  42  Delivery_Year                           16947 non-null  int64
#  43  TRF                                     16947 non-null  int64
#  44  Total_Amount_Currency                   16947 non-null  object
#  45  Total_Amount                            16888 non-null  float64
#  46  Total_Taxable_Amount_Currency           16947 non-null  object
#  47  Total_Taxable_Amount                    16947 non-null  float64
#  48  Stage                                   16947 non-null  object
# dtypes: bool(4), float64(4), int64(5), object(36)
# memory usage: 5.9+ MB

# %%
df['Region'].value_counts()
# Out:
# Japan          4892
# EMEA           4664
# Americas       3945
# APAC           3262
# Middle East     184
# Name: Region, dtype: int64

# %%
df['Stage'].value_counts()
# Out:
# Closed Won       9533
# Closed Lost      7350
# Proposal           35
# Negotiation        18
# Qualification      11
# Name: Stage, dtype: int64

# %%
df['ASP_(converted)_Currency'].value_counts()
# Out:
# USD    16947
# Name: ASP_(converted)_Currency, dtype: int64

# %%
df['indice_convertidor']=df['ASP_(converted)']/df['ASP']
df.head()
# Out:
#    Unnamed: 0     ID    Region   Territory  \
# 0           0  27761      EMEA        None
# 1           1  27760      EMEA        None
# 2           2  27446  Americas  NW America
# 3           3  16808  Americas  NW America
# 4           4  16805  Americas  NW America
#
#    Pricing, Delivery_Terms_Quote_Approval  Pricing, Delivery_Terms_Approved  \
# 0                                    True                              True
# 1                                   False                             False
# 2                                   False                             False
# 3                                    True                             False
# 4                                    True                             False
#
#    Bureaucratic_Code_0_Approval  Bureaucratic_Code_0_Approved  \
# 0                          True                          True
# 1                         False                         False
# 2                         False                         False
# 3                          True                         False
# 4                          True                         False
#
#      Bureaucratic_Code Account_Created_Date  ...       Month Delivery_Quarter  \
# 0  Bureaucratic_Code_4           2015-06-16  ...  2016-05-01               Q2
# 1  Bureaucratic_Code_4           2015-06-16  ...  2016-01-01               Q1
# 2  Bureaucratic_Code_4           2015-04-21  ...  2016-01-01               Q1
# 3  Bureaucratic_Code_5           2013-07-27  ...  2018-02-01               Q1
# 4  Bureaucratic_Code_5           2013-07-27  ...  2018-02-01               Q1
#
#   Delivery_Year TRF  Total_Amount_Currency Total_Amount  \
# 0          2016  10                    EUR    5272800.0
# 1          2016   0                    EUR      48230.0
# 2          2016   0                    USD      83865.6
# 3          2018  14                    USD    7421881.5
# 4          2018  25                    USD   13357192.5
#
#   Total_Taxable_Amount_Currency Total_Taxable_Amount        Stage  \
# 0                           EUR            5272800.0  Closed Lost
# 1                           EUR              48230.0   Closed Won
# 2                           USD              83865.6   Closed Won
# 3                           USD            7421881.5  Closed Lost
# 4                           USD           13357192.5  Closed Lost
#
#   indice_convertidor
# 0           1.131096
# 1           1.131094
# 2           1.000000
# 3           1.000000
# 4           1.000000
#
# [5 rows x 50 columns]

# %%
df['Total_Amount(converted)']=(df['Total_Amount']*df['indice_convertidor'])//1
df['indice_convertidor'].value_counts()
# Out:
# 1.000000    6837
# 1.131100     253
# 1.131083     234
# 1.131105     230
# 1.131095     219
#             ...
# 0.009060       1
# 0.008886       1
# 0.008982       1
# 1.131080       1
# 1.131101       1
# Name: indice_convertidor, Length: 201, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0     ID    Region   Territory  \
# 0           0  27761      EMEA        None
# 1           1  27760      EMEA        None
# 2           2  27446  Americas  NW America
# 3           3  16808  Americas  NW America
# 4           4  16805  Americas  NW America
#
#    Pricing, Delivery_Terms_Quote_Approval  Pricing, Delivery_Terms_Approved  \
# 0                                    True                              True
# 1                                   False                             False
# 2                                   False                             False
# 3                                    True                             False
# 4                                    True                             False
#
#    Bureaucratic_Code_0_Approval  Bureaucratic_Code_0_Approved  \
# 0                          True                          True
# 1                         False                         False
# 2                         False                         False
# 3                          True                         False
# 4                          True                         False
#
#      Bureaucratic_Code Account_Created_Date  ... Delivery_Quarter  \
# 0  Bureaucratic_Code_4           2015-06-16  ...               Q2
# 1  Bureaucratic_Code_4           2015-06-16  ...               Q1
# 2  Bureaucratic_Code_4           2015-04-21  ...               Q1
# 3  Bureaucratic_Code_5           2013-07-27  ...               Q1
# 4  Bureaucratic_Code_5           2013-07-27  ...               Q1
#
#   Delivery_Year TRF Total_Amount_Currency  Total_Amount  \
# 0          2016  10                   EUR     5272800.0
# 1          2016   0                   EUR       48230.0
# 2          2016   0                   USD       83865.6
# 3          2018  14                   USD     7421881.5
# 4          2018  25                   USD    13357192.5
#
#   Total_Taxable_Amount_Currency Total_Taxable_Amount        Stage  \
# 0                           EUR            5272800.0  Closed Lost
# 1                           EUR              48230.0   Closed Won
# 2                           USD              83865.6   Closed Won
# 3                           USD            7421881.5  Closed Lost
# 4                           USD           13357192.5  Closed Lost
#
#   indice_convertidor Total_Amount(converted)
# 0           1.131096               5964043.0
# 1           1.131094                 54552.0
# 2           1.000000                 83865.0
# 3           1.000000               7421881.0
# 4           1.000000              13357192.0
#
# [5 rows x 51 columns]

# %%
df_closed=df.loc[(df['Stage']=='Closed Lost') | (df['Stage']=='Closed Won')]
df_closed['Stage'].value_counts()
# Out:
# Closed Won     9533
# Closed Lost    7350
# Name: Stage, dtype: int64

# %%
closed= df_closed.groupby(['Region','Delivery_Year','Stage'])\
.agg({'Opportunity_ID':['count'],'Total_Amount(converted)':['sum']}).dropna()
closed.head()
# Out:
#                                  Opportunity_ID Total_Amount(converted)
#                                           count                     sum
# Region Delivery_Year Stage
# APAC   2016          Closed Lost            185            3.032875e+08
#                      Closed Won             365            4.496674e+07
#        2017          Closed Lost            427            1.090661e+09
#                      Closed Won             846            9.705494e+07
#        2018          Closed Lost            660            1.686024e+09

# %%
level0 = closed.columns.get_level_values(0)
level1 = closed.columns.get_level_values(1)
closed.columns= level0 + '_' + level1
closed =closed.reset_index()
closed
# Out:
#          Region  Delivery_Year        Stage  Opportunity_ID_count  \
# 0          APAC           2016  Closed Lost                   185
# 1          APAC           2016   Closed Won                   365
# 2          APAC           2017  Closed Lost                   427
# 3          APAC           2017   Closed Won                   846
# 4          APAC           2018  Closed Lost                   660
# 5          APAC           2018   Closed Won                   676
# 6          APAC           2019  Closed Lost                    83
# 7          APAC           2019   Closed Won                     9
# 8      Americas           2016  Closed Lost                   399
# 9      Americas           2016   Closed Won                   313
# 10     Americas           2017  Closed Lost                   790
# 11     Americas           2017   Closed Won                   622
# 12     Americas           2018  Closed Lost                   883
# 13     Americas           2018   Closed Won                   821
# 14     Americas           2019  Closed Lost                    68
# 15     Americas           2019   Closed Won                    37
# 16         EMEA           2016  Closed Lost                   495
# 17         EMEA           2016   Closed Won                   469
# 18         EMEA           2017  Closed Lost                   722
# 19         EMEA           2017   Closed Won                  1027
# 20         EMEA           2018  Closed Lost                   913
# 21         EMEA           2018   Closed Won                   939
# 22         EMEA           2019  Closed Lost                    59
# 23         EMEA           2019   Closed Won                    36
# 24        Japan           2016  Closed Lost                  1147
# 25        Japan           2016   Closed Won                   985
# 26        Japan           2017  Closed Lost                   224
# 27        Japan           2017   Closed Won                  1582
# 28        Japan           2018  Closed Lost                   126
# 29        Japan           2018   Closed Won                   734
# 30        Japan           2019  Closed Lost                    49
# 31        Japan           2019   Closed Won                    22
# 32  Middle East           2016  Closed Lost                     8
# 33  Middle East           2016   Closed Won                     5
# 34  Middle East           2017  Closed Lost                    59
# 35  Middle East           2017   Closed Won                    18
# 36  Middle East           2018  Closed Lost                    52
# 37  Middle East           2018   Closed Won                    26
# 38  Middle East           2019  Closed Lost                     1
# 39  Middle East           2019   Closed Won                     1
#
#     Total_Amount(converted)_sum
# 0                  3.032875e+08
# 1                  4.496674e+07
# 2                  1.090661e+09
# 3                  9.705494e+07
# 4                  1.686024e+09
# 5                  5.832741e+07
# 6                  6.540368e+08
# 7                  1.050635e+06
# 8                  2.702654e+09
# 9                  3.851086e+08
# 10                 1.690840e+09
# 11                 1.556533e+08
# 12                 1.687869e+09
# 13                 1.793958e+08
# 14                 6.065449e+08
# 15                 2.575991e+07
# 16                 1.096988e+09
# 17                 2.083012e+08
# 18                 1.861390e+09
# 19                 2.207685e+08
# 20                 1.001930e+09
# 21                 1.471055e+08
# 22                 2.078584e+08
# 23                 3.765474e+06
# 24                 1.486719e+07
# 25                 5.841026e+07
# 26                 5.983579e+07
# 27                 3.750323e+07
# 28                 1.222230e+08
# 29                 1.997370e+07
# 30                 4.365454e+07
# 31                 7.368630e+05
# 32                 7.429077e+06
# 33                 1.454938e+06
# 34                 1.799840e+08
# 35                 1.240323e+06
# 36                 1.024539e+08
# 37                 1.933824e+06
# 38                 1.216050e+05
# 39                 1.216050e+05

# %%
closed['Opportunity_ID_count'].sum()
# Out:
# 16883

# %% [markdown]
# # Gráficos

# %%
x0=closed.loc[(closed['Region']=='Americas')&(closed['Stage']=='Closed Won')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x0
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                           313
# 2017                           622
# 2018                           821
# 2019                            37

# %%
x1=closed.loc[(closed['Region']=='Americas')&(closed['Stage']=='Closed Lost')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x1
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                           399
# 2017                           790
# 2018                           883
# 2019                            68

# %%
x2=closed.loc[(closed['Region']=='EMEA')&(closed['Stage']=='Closed Won')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x2
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                           469
# 2017                          1027
# 2018                           939
# 2019                            36

# %%
x3=closed.loc[(closed['Region']=='EMEA')&(closed['Stage']=='Closed Lost')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x3
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                           495
# 2017                           722
# 2018                           913
# 2019                            59

# %%
x4=closed.loc[(closed['Region']=='APAC')&(closed['Stage']=='Closed Won')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x4
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                           365
# 2017                           846
# 2018                           676
# 2019                             9

# %%
x5=closed.loc[(closed['Region']=='APAC')&(closed['Stage']=='Closed Lost')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x5
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                           185
# 2017                           427
# 2018                           660
# 2019                            83

# %%
x6=closed.loc[(closed['Region']=='Middle East')&(closed['Stage']=='Closed Won')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x6
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                             5
# 2017                            18
# 2018                            26
# 2019                             1

# %%
x7=closed.loc[(closed['Region']=='Middle East')&(closed['Stage']=='Closed Lost')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x7
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                             8
# 2017                            59
# 2018                            52
# 2019                             1

# %%
x8=closed.loc[(closed['Region']=='Japan')&(closed['Stage']=='Closed Won')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x8
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                           985
# 2017                          1582
# 2018                           734
# 2019                            22

# %%
x9=closed.loc[(closed['Region']=='Japan')&(closed['Stage']=='Closed Lost')].groupby(['Delivery_Year'])\
.agg({'Opportunity_ID_count':['sum']}).dropna()
x9
# Out:
#               Opportunity_ID_count
#                                sum
# Delivery_Year
# 2016                          1147
# 2017                           224
# 2018                           126
# 2019                            49

# %%
labels = ['2016', '2017', '2018', '2019']
Won = [313,622, 821, 37]
Lost = [399, 790, 883, 68]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Won, width, label='Closed Won')
rects2 = ax.bar(x + width/2, Lost, width, label='Closed Lost')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# de Oportunidades')
ax.set_title('Evolución de oportunidades - Región: Americas')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Figura 11

# %%
labels = ['2016', '2017', '2018', '2019']
Won = [469,1027, 939, 36]
Lost = [495, 722, 913, 59]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Won, width, label='Closed Won')
rects2 = ax.bar(x + width/2, Lost, width, label='Closed Lost')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# de Oportunidades')
ax.set_title('Evolución de oportunidades - Región: EMEA')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Figura 12

# %%
labels = ['2016', '2017', '2018', '2019']
Won = [365,846,676,9 ]
Lost = [185,427,660,83]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Won, width, label='Closed Won')
rects2 = ax.bar(x + width/2, Lost, width, label='Closed Lost')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# de Oportunidades')
ax.set_title('Evolución de oportunidades - Región: APAC')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Figura 13

# %%
labels = ['2016', '2017', '2018', '2019']
Won = [5,18,26,1]
Lost = [8,59,52,1]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Won, width, label='Closed Won')
rects2 = ax.bar(x + width/2, Lost, width, label='Closed Lost')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# de Oportunidades')
ax.set_title('Evolución de oportunidades - Región: Middle East')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Figura 14

# %%
labels = ['2016', '2017', '2018', '2019']
Won = [985,1582,734,22]
Lost = [1147,224,126,49]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Won, width, label='Closed Won')
rects2 = ax.bar(x + width/2, Lost, width, label='Closed Lost')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# de Oportunidades')
ax.set_title('Evolución de oportunidades - Región: Japan')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Figura 15
